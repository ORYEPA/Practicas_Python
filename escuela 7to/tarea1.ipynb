# %%
#primer punto de la tarea

saludar= " hola este es un programa para aprender las tablas de multiplicar"
print (saludar)
numTabla=float(input("Con que numero quieres practicar?"))
print(numTabla)
aciertos=0
for i in range(1,11):
     
    numMultiplo = float(input("Empecemos, ¿cuál es el resultado de multiplicar {} por {}? ".format(numTabla, i)))
    resultado = numTabla * i
    if (numTabla * i == numMultiplo):
        print(f"Correcto, El resultado de {numTabla} multiplicado por {i} es {resultado}")
        aciertos +=1 
    else:
        
        print(f"Error, El resultado de {numTabla} multiplicado por {i} es {resultado}")


print(f"Excelente has obtenido {aciertos} aciertos de 10")
# Out:
#  hola este es un programa para aprender las tablas de multiplicar
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 5
#       3 saludar= " hola este es un programa para aprender las tablas de multiplicar"
#       4 print (saludar)
# ----> 5 numTabla=float(input("Con que numero quieres practicar?"))
#       6 print(numTabla)
#       7 aciertos=0
#
# ValueError: could not convert string to float: ''

# %%
#2 tarea
# Lista inicial de artículos
articulos = []

# Función para calcular el costo de producción
def calcular_costo_produccion(articulo):
    cantidad = articulo["Cantidad"]
    factor_materiales = articulo["Factor_Materiales"]
    costo_fijo = articulo["Costo_Fijo"]
    costo_produccion = cantidad * factor_materiales + costo_fijo
    return costo_produccion

# Función para agregar un nuevo artículo
def agregar_articulo():
    nombre = input("Ingrese el nombre del artículo: ")
    descripcion = input("Ingrese la descripción del artículo: ")
    cantidad = float(input("Ingrese la cantidad de unidades producidas: "))
    factor_materiales = float(input("Ingrese el factor de costo de materiales: "))
    costo_fijo = float(input("Ingrese el costo fijo: "))

    articulo = {
        "Nombre": nombre,
        "Descripcion": descripcion,
        "Cantidad": cantidad,
        "Factor_Materiales": factor_materiales,
        "Costo_Fijo": costo_fijo
    }

    articulos.append(articulo)
    print(f"El artículo '{nombre}' ha sido agregado correctamente.")

# Generar el informe
while True:
    print("\n1. Agregar nuevo artículo")
    print("2. Generar informe de Costos de Producción")
    print("3. Salir")

    opcion = input("Seleccione una opción: ")

    if opcion == "1":
        agregar_articulo()
    elif opcion == "2":
        print("\nInforme de Costos de Producción\n")
        print("{:<30} {:<20} {:<15} {:<15} {:<20}".format("Nombre del Artículo", "Unidades Producidas", "Factor de Costo", "Costo Fijo", "Costo de Producción"))
        print("="*100)

        total_unidades_producidas = 0
        total_factor_costo = 0
        total_costo_fijo = 0
        total_costo_produccion = 0

        for articulo in articulos:
            nombre = articulo["Nombre"]
            unidades_producidas = articulo["Cantidad"]
            factor_costo = articulo["Factor_Materiales"]
            costo_fijo = articulo["Costo_Fijo"]
            costo_produccion = calcular_costo_produccion(articulo)

            total_unidades_producidas += unidades_producidas
            total_factor_costo += factor_costo
            total_costo_fijo += costo_fijo
            total_costo_produccion += costo_produccion

            print("{:<30} {:<20} {:<15} {:<15} {:<20}".format(nombre, unidades_producidas, factor_costo, costo_fijo, costo_produccion))
        
        print("-" * 100)
        print("{:<30} {:<20} {:<15} {:<15} {:<20}".format("Total:", total_unidades_producidas, total_factor_costo, total_costo_fijo, total_costo_produccion))
    elif opcion == "3":
        break
    else:
        print("Opción no válida. Por favor, seleccione una opción válida.")
# Out:
# 1. Agregar nuevo artículo
# 2. Generar informe de Costos de Producción
# 3. Salir
# El artículo 'pluma' ha sido agregado correctamente.
#
# 1. Agregar nuevo artículo
# 2. Generar informe de Costos de Producción
# 3. Salir
# El artículo 'lapiz{' ha sido agregado correctamente.
#
# 1. Agregar nuevo artículo
# 2. Generar informe de Costos de Producción
# 3. Salir
#
# Informe de Costos de Producción
#
# Nombre del Artículo            Unidades Producidas  Factor de Costo Costo Fijo      Costo de Producción
# ...
# pluma                          100.0                1.0             2.0             102.0
# lapiz{                         330.0                2.0             9.0             669.0
# ----------------------------------------------------------------------------------------------------
# Total:                         430.0                3.0             11.0            771.0
#
# 1. Agregar nuevo artículo
# 2. Generar informe de Costos de Producción
# 3. Salir
#
# ...

# %%
#3 tarea
# Lista inicial de artículos
articulos = []

# Función para calcular el costo de producción
def calcular_costo_produccion(articulo):
    cantidad = articulo["Cantidad"]
    factor_materiales = articulo["Factor_Materiales"]
    costo_fijo = articulo["Costo_Fijo"]
    costo_produccion = cantidad * factor_materiales + costo_fijo
    return costo_produccion

# Función para agregar un nuevo artículo
def agregar_articulo():
    nombre = input("Ingrese el nombre del artículo: ")
    descripcion = input("Ingrese la descripción del artículo: ")
    cantidad = float(input("Ingrese la cantidad de unidades producidas: "))
    factor_materiales = float(input("Ingrese el factor de costo de materiales: "))
    costo_fijo = float(input("Ingrese el costo fijo: "))

    articulo = {
        "Nombre": nombre,
        "Descripcion": descripcion,
        "Cantidad": cantidad,
        "Factor_Materiales": factor_materiales,
        "Costo_Fijo": costo_fijo
    }

    articulos.append(articulo)
    print(f"El artículo '{nombre}' ha sido agregado correctamente.")
def calcular_utilidad(costo_produccion):
    return 1.2 * costo_produccion

# Función para calcular el impuesto
def calcular_impuesto(costo_produccion, utilidad):
    return 0.15 * (costo_produccion + utilidad)

# Función para calcular el precio de venta
def calcular_precio_venta(costo_produccion, utilidad, impuesto):
    return costo_produccion + utilidad + impuesto

# Generar el nuevo informe
while True:
    print("\n1. Agregar nuevo artículo")
    print("2. Generar informe de Costos y Precios de Venta")
    print("3. Salir")

    opcion = input("Seleccione una opción: ")

    if opcion == "1":
        agregar_articulo()
    elif opcion == "2":
        print("\nInforme de Costos y Precios de Venta\n")
        print("{:<30} {:<20} {:<20} {:<20} {:<20} {:<20}".format("Nombre del Artículo", "Descripción", "Costo de Producción", "Utilidad", "Impuesto", "Precio de Venta"))
        print("="*130)

        for articulo in articulos:
            nombre = articulo["Nombre"]
            descripcion = articulo["Descripcion"]
            costo_produccion = calcular_costo_produccion(articulo)
            utilidad = calcular_utilidad(costo_produccion)
            impuesto = calcular_impuesto(costo_produccion, utilidad)
            precio_venta = calcular_precio_venta(costo_produccion, utilidad, impuesto)

            print("{:<30} {:<20} {:<20} {:<20} {:<20} {:<20}".format(nombre, descripcion, costo_produccion, utilidad, impuesto, precio_venta))
        
        print("-" * 130)
    elif opcion == "3":
        break
    else:
                print("Opción no válida. Por favor, seleccione una opción válida.")
# Out:
# 1. Agregar nuevo artículo
# 2. Generar informe de Costos y Precios de Venta
# 3. Salir
# El artículo 'cuaderno' ha sido agregado correctamente.
#
# 1. Agregar nuevo artículo
# 2. Generar informe de Costos y Precios de Venta
# 3. Salir
# El artículo 'lapiz' ha sido agregado correctamente.
#
# 1. Agregar nuevo artículo
# 2. Generar informe de Costos y Precios de Venta
# 3. Salir
#
# Informe de Costos y Precios de Venta
#
# Nombre del Artículo            Descripción          Costo de Producción  Utilidad             Impuesto             Precio de Venta
# ...
# cuaderno                       a4                   50110.0              60132.0              16536.3              126778.3
# lapiz                          amarilo              150010.0             180012.0             49503.299999999996   379525.3
# ----------------------------------------------------------------------------------------------------------------------------------
#
# 1. Agregar nuevo artículo
# ...
