# %%
from PIL import Image
import numpy as np #importe de libreria
from matplotlib import pyplot as plt #pa plotear
import cv2 as cv
img=Image.open('mamo.png').convert('L')
#img_gray.save('testbw.png')

#img_gray2=Image.open('testbw.png')
fig1, ax1=plt.subplots()
ax1.imshow(img)
# fig2, ax2=plt.subplots()
# ax2.imshow(img_gray2,cmap="gray",vmin=0,vmax=255)

# %%
# img=Image.open('testbw.png')
pix_val=list(img.getdata())

# %%
print("Maximo= ", np.max(pix_val))
print("Minimo= ", np.min(pix_val))
# Out:
# Maximo=  255
# Minimo=  0

# %%
img=np.array(img)
[n,m]=img.shape
print(n)
print(m)
#convertimos imagen en matriz
# Out:
# 1248
# 768

# %%
import cv2
ksize=(20,20)
blur = cv.blur(img,ksize) 
ret,thresh1 = cv.threshold(blur,230,255,cv.THRESH_BINARY)
plt.imshow(thresh1,cmap='gray')

# %%
import cv2 
import numpy as np    
# path to input image is specified and  
# image is loaded with imread command 
image1 = img
umbral,img_bin=cv2.threshold(img,30,255,cv2.THRESH_OTSU)
            


ada,thresh2 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
ret,thresh3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
ret,thresh4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
ret,thresh5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)



    

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img ,thresh1, thresh2, thresh3, thresh4, thresh5]
for i in range(6):
    plt.subplot(3,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec


fig = plt.figure(constrained_layout=True)

gs = GridSpec(3, 3, figure=fig)
image1 = img
axs = fig.add_subplot(gs[0, :])
axs.imshow(img)
# ax.set_ylabel('YLabel0')
# ax.set_xlabel('XLabel0')

bw_img=np.zeros(img.shape)
for i in range(n):
    for j in range(m):
        if img[i,j]>0:
            bw_img[i,j]=1
        else:
            bw_img[i,j]=0 

ada,thresh2 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
ret,thresh3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
ret,thresh4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
ret,thresh5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)

images = [thresh1, thresh2, thresh3, thresh4, thresh5,bw_img]

for i in range(6):
    ax = fig.add_subplot(gs[i+3])
    ax.imshow(images[i],'gray',vmin=0,vmax=255)
    # ax.set_ylabel('YLabel1 %d' % i)
    # ax.set_xlabel('XLabel1 %d' % i)
   
fig.align_labels()  # same as fig.align_xlabels(); fig.align_ylabels()

plt.show()

# %%
ksize=(20,20)
blur = cv.blur(img,ksize) #blur image, reduce noise

#ret,thresh1 = cv.threshold(blur,230,255,cv.THRESH_BINARY)
#ret,thresh1 =cv.threshold(img,230,255,cv.THRESH_BINARY)
# umbral,img_bin=plt.threshold(img,110,255,plt.THRESH_BINARY+plt.THRESH_OTSU)
canny = cv.Canny(thresh1, 30, 150, 3) #edge detection

dilated = cv.dilate(canny, (1, 1), iterations=0)

(cnt, hierarchy) = cv.findContours(
    dilated.copy(), cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)
rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.drawContours(rgb, cnt, -1, (0, 255, 0), 2)

plt.imshow(thresh1, cmap='gray')
print("figuras en la imagen: ", len(cnt))

# plt.imshow(thresh1,"gray",vmin=0,vmax=255)
plt.axis("off")
# Out:
# figuras en la imagen:  2
# (-0.5, 767.5, 1247.5, -0.5)
